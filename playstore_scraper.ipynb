# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
import csv
import time
from google_play_scraper import reviews, Sort

APP_ID = "com.wemabank.alat.prod"  # ALAT app package name
MAX_REVIEWS = 40000               # Target number of reviews
BATCH_SIZE = 200                  # How many reviews to fetch per request
OUTPUT_FILE = "alat_reviews.csv"

def scrape_reviews():
    all_reviews = []
    continuation_token = None

    print(f"Starting scraping for {APP_ID}... Target: {MAX_REVIEWS} reviews.")

    while len(all_reviews) < MAX_REVIEWS:
        try:
            result, continuation_token = reviews(
                APP_ID,
                lang='en',
                country='ng',
                sort=Sort.NEWEST,
                count=BATCH_SIZE,
                continuation_token=continuation_token
            )

            if not result:  # Stop if no more reviews
                print("No more reviews found.")
                break

            all_reviews.extend(result)
            print(f"Fetched {len(all_reviews)} reviews so far...")

            if continuation_token is None:  # Stop if no more pages
                print("Reached the end of available reviews.")
                break

            time.sleep(1)  # Pause to avoid getting rate-limited

        except Exception as e:
            print(f"Error occurred: {e}")
            break

    print(f"Scraping complete. Total reviews fetched: {len(all_reviews)}")
    return all_reviews

def save_to_csv(reviews_list):
    with open(OUTPUT_FILE, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerow(["UserName", "Rating", "Review", "Date", "ThumbsUp"])
        for r in reviews_list:
            writer.writerow([
                r["userName"],
                r["score"],
                r["content"].replace("\n", " "),  # Clean newlines
                r["at"].strftime("%Y-%m-%d %H:%M:%S"),
                r["thumbsUpCount"]
            ])
    print(f"Reviews saved to {OUTPUT_FILE}")

if __name__ == "__main__":
    reviews_data = scrape_reviews()
    save_to_csv(reviews_data)
# Out:
# Starting scraping for com.wemabank.alat.prod... Target: 40000 reviews.
# Fetched 200 reviews so far...
# Fetched 400 reviews so far...
# Fetched 600 reviews so far...
# Fetched 800 reviews so far...
# Fetched 1000 reviews so far...
# Fetched 1200 reviews so far...
# Fetched 1400 reviews so far...
# Fetched 1600 reviews so far...
# Fetched 1800 reviews so far...
# Fetched 2000 reviews so far...
# Fetched 2200 reviews so far...
# Fetched 2400 reviews so far...
# Fetched 2600 reviews so far...
# Fetched 2800 reviews so far...
# Fetched 3000 reviews so far...
# Fetched 3200 reviews so far...
# Fetched 3400 reviews so far...
# Fetched 3600 reviews so far...
# Fetched 3800 reviews so far...
# Fetched 4000 reviews so far...
# Fetched 4200 reviews so far...
# Fetched 4400 reviews so far...
# Fetched 4600 reviews so far...
# Fetched 4800 reviews so far...
# Fetched 5000 reviews so far...
# Fetched 5200 reviews so far...
# Fetched 5400 reviews so far...
# Fetched 5600 reviews so far...
# Fetched 5800 reviews so far...
# Fetched 6000 reviews so far...
# Fetched 6200 reviews so far...
# Fetched 6400 reviews so far...
# Fetched 6600 reviews so far...
# Fetched 6800 reviews so far...
# Fetched 7000 reviews so far...
# Fetched 7200 reviews so far...
# Fetched 7400 reviews so far...
# Fetched 7600 reviews so far...
# Fetched 7800 reviews so far...
# Fetched 8000 reviews so far...
# Fetched 8200 reviews so far...
# Fetched 8400 reviews so far...
# Fetched 8600 reviews so far...
# Fetched 8800 reviews so far...
# Fetched 9000 reviews so far...
# Fetched 9200 reviews so far...
# Fetched 9400 reviews so far...
# Fetched 9600 reviews so far...
# Fetched 9800 reviews so far...
# Fetched 10000 reviews so far...
# Fetched 10200 reviews so far...
# Fetched 10400 reviews so far...
# Fetched 10600 reviews so far...
# Fetched 10800 reviews so far...
# Fetched 11000 reviews so far...
# Fetched 11200 reviews so far...
# Fetched 11400 reviews so far...
# Fetched 11600 reviews so far...
# Fetched 11800 reviews so far...
# Fetched 12000 reviews so far...
# Fetched 12200 reviews so far...
# Fetched 12400 reviews so far...
# Fetched 12600 reviews so far...
# Fetched 12800 reviews so far...
# Fetched 13000 reviews so far...
# Fetched 13200 reviews so far...
# Fetched 13400 reviews so far...
# Fetched 13600 reviews so far...
# Fetched 13800 reviews so far...
# Fetched 14000 reviews so far...
# Fetched 14200 reviews so far...
# Fetched 14400 reviews so far...
# Fetched 14600 reviews so far...
# Fetched 14800 reviews so far...
# Fetched 15000 reviews so far...
# Fetched 15200 reviews so far...
# Fetched 15400 reviews so far...
# Fetched 15600 reviews so far...
# Fetched 15800 reviews so far...
# Fetched 16000 reviews so far...
# Fetched 16200 reviews so far...
# Fetched 16400 reviews so far...
# Fetched 16600 reviews so far...
# Fetched 16800 reviews so far...
# Fetched 17000 reviews so far...
# Fetched 17200 reviews so far...
# Fetched 17400 reviews so far...
# Fetched 17600 reviews so far...
# Fetched 17800 reviews so far...
# Fetched 18000 reviews so far...
# Fetched 18200 reviews so far...
# Fetched 18400 reviews so far...
# Fetched 18600 reviews so far...
# Fetched 18800 reviews so far...
# Fetched 19000 reviews so far...
# Fetched 19200 reviews so far...
# Fetched 19400 reviews so far...
# Fetched 19600 reviews so far...
# Fetched 19800 reviews so far...
# Fetched 20000 reviews so far...
# Fetched 20200 reviews so far...
# Fetched 20400 reviews so far...
# Fetched 20600 reviews so far...
# Fetched 20800 reviews so far...
# Fetched 21000 reviews so far...
# Fetched 21200 reviews so far...
# Fetched 21400 reviews so far...
# Fetched 21600 reviews so far...
# Fetched 21800 reviews so far...
# Fetched 22000 reviews so far...
# Fetched 22200 reviews so far...
# Fetched 22400 reviews so far...
# Fetched 22600 reviews so far...
# Fetched 22800 reviews so far...
# Fetched 23000 reviews so far...
# Fetched 23200 reviews so far...
# Fetched 23400 reviews so far...
# Fetched 23600 reviews so far...
# Fetched 23670 reviews so far...
# No more reviews found.
# Scraping complete. Total reviews fetched: 23670
# Reviews saved to alat_reviews.csv
